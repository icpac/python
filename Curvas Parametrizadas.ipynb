# %%
__author__ = "Tlacaelel iCPAc"
__email__ = "tlacaelel.icpac@gmail.com"

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
t = np.linspace(0, 2*np.pi, 70)

def xt(t):
    return (1+2*np.cos(t))*np.cos(t)

def yt(t):
    return (1+2*np.cos(t))*np.sin(t)


#plt.xticks([])
#plt.yticks([])
plt.grid(True)  


plt.plot(xt(t), yt(t))
plt.title("limacon")
# Out:
# Text(0.5, 1.0, 'limacon')

# %%
t = np.linspace(0, 2*np.pi, 70)

plt.grid(True)  

plt.plot(np.cos(t)**3, np.sin(t)**3)
plt.title("Astroide")
# Out:
# Text(0.5, 1.0, 'Astroide')
